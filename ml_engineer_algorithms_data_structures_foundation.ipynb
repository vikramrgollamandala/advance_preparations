# %% [markdown]
# # ML Engineer Algorithms and Data Structures Foundation
#
# This notebook is designed to strengthen algorithms and data structures with an ML engineering lens.
#
# Focus:
# - strong coding fundamentals
# - real-world ML use cases
# - production-oriented reasoning
# - time and space complexity awareness
#
# How to use this notebook:
# 1. Read the concept and use case.
# 2. Implement the function or class.
# 3. Run the sample checks.
# 4. Answer the follow-up about scale or production use.

# %%
from collections import Counter, defaultdict, deque
import heapq
from bisect import bisect_left, bisect_right
from dataclasses import dataclass
from typing import List, Dict, Tuple, Optional, Iterable

# %% [markdown]
# ## Shared Sample Data
#
# Use these inputs to test the exercises before writing your own edge cases.

# %%
sample_tokens = [
    "model", "feature", "model", "inference", "feature", "feature", "latency", "model", "cache", "cache"
]
sample_k = 3

sample_scores = [0.05, 0.12, 0.18, 0.67, 0.71, 0.89]
sample_threshold = 0.7

sample_predictions = [
    ("item_1", 0.82),
    ("item_2", 0.91),
    ("item_3", 0.77),
    ("item_4", 0.95),
    ("item_5", 0.66),
]
sample_top_n = 3

sample_stream = [1.2, 3.5, 0.8, 9.1, 4.4, 7.0, 2.3]
sample_stream_k = 3

sample_window_values = [1.0, 12.0, -5.0, -6.0, 50.0, 3.0]
sample_window_size = 4

sample_sorted_values = [0.1, 0.3, 0.5, 0.7, 0.9]
sample_insert_target = 0.6

sample_batch_items = ["req_1", "req_2", "req_3", "req_4", "req_5"]
sample_batch_size = 2

sample_parentheses = "([]){}"
sample_invalid_parentheses = "([)]"

sample_graph = {
    "raw_data": ["clean_data", "bad_records"],
    "clean_data": ["features", "training_set"],
    "features": ["inference_store"],
    "training_set": [],
    "inference_store": [],
    "bad_records": []
}
sample_graph_start = "raw_data"

sample_edit_a = "kitten"
sample_edit_b = "sitting"

sample_trie_words = ["cat", "car", "care", "dog", "dove"]
sample_trie_search_word = "care"
sample_trie_prefix = "ca"

sample_cache_capacity = 2
sample_cache_ops = [
    ("put", "feature:U1", 0.81),
    ("put", "feature:U2", 0.63),
    ("get", "feature:U1"),
    ("put", "feature:U3", 0.91),
    ("get", "feature:U2"),
]

sample_intervals = [[1, 3], [2, 6], [8, 10], [15, 18]]

sample_prefix_nums = [2, 4, 6, 8, 10]
sample_range_left = 1
sample_range_right = 3

sample_sorted_dupes = [1, 1, 2, 2, 3, 4, 4, 5]

print("sample_tokens:", sample_tokens)
print("sample_scores:", sample_scores)
print("sample_predictions:", sample_predictions)
print("sample_graph keys:", list(sample_graph.keys()))

# %% [markdown]
# ## 1. Hash Map / Dictionary
#
# Real-world ML use cases:
# - counting token frequency
# - feature dictionary lookups
# - caching expensive preprocessing results
#
# Question:
# Implement `top_k_tokens(tokens, k)` that returns the top `k` most frequent tokens sorted by frequency descending.

# %%
def top_k_tokens(tokens: List[str], k: int) -> List[Tuple[str, int]]:
    # TODO
    raise NotImplementedError

# %% [markdown]
# Follow-up:
# - How would this change for a streaming vocabulary counter?
# - When would you use approximate counting instead of exact counting?

# %% [markdown]
# ## 2. Array / List Scanning
#
# Real-world ML use cases:
# - scanning prediction scores
# - post-processing ranked outputs
# - finding threshold crossings
#
# Question:
# Implement `first_threshold_crossing(scores, threshold)` that returns the first index where score is greater than or equal to the threshold. Return `-1` if not found.

# %%
def first_threshold_crossing(scores: List[float], threshold: float) -> int:
    # TODO
    raise NotImplementedError

# %% [markdown]
# ## 3. Sorting and Top-N Selection
#
# Real-world ML use cases:
# - retrieving top recommendations
# - picking top model candidates
# - pruning large result sets
#
# Question:
# Implement `top_n_predictions(items, n)` where `items` is a list of `(id, score)` tuples. Return the top `n` by score descending.

# %%
def top_n_predictions(items: List[Tuple[str, float]], n: int) -> List[Tuple[str, float]]:
    # TODO
    raise NotImplementedError

# %% [markdown]
# Follow-up:
# - When is full sorting wasteful?
# - When would a heap be better than sorting the whole list?

# %% [markdown]
# ## 4. Heap / Priority Queue
#
# Real-world ML use cases:
# - beam search
# - top-k retrieval
# - scheduling background inference jobs
#
# Question:
# Implement `running_top_k(stream, k)` that processes a stream of numeric scores and returns the current top `k` largest values.

# %%
def running_top_k(stream: Iterable[float], k: int) -> List[float]:
    # TODO
    raise NotImplementedError

# %% [markdown]
# ## 5. Sliding Window
#
# Real-world ML use cases:
# - rolling metrics
# - monitoring drift windows
# - sequence anomaly detection
#
# Question:
# Implement `max_average_window(values, window_size)` that returns the maximum average over any contiguous window of size `window_size`.

# %%
def max_average_window(values: List[float], window_size: int) -> float:
    # TODO
    raise NotImplementedError

# %% [markdown]
# ## 6. Binary Search
#
# Real-world ML use cases:
# - threshold tuning
# - searching sorted embeddings metadata
# - selecting calibration cutoffs
#
# Question:
# Implement `find_insert_position(sorted_values, target)` that returns the index where `target` should be inserted to keep the list sorted.

# %%
def find_insert_position(sorted_values: List[float], target: float) -> int:
    # TODO
    raise NotImplementedError

# %% [markdown]
# ## 7. Queue / Deque
#
# Real-world ML use cases:
# - batching requests for inference
# - streaming event buffers
# - asynchronous preprocessing pipelines
#
# Question:
# Implement a class `FixedBatchQueue(batch_size)` with methods:
# - `add(item)`
# - `pop_batch()` -> returns up to `batch_size` items in arrival order

# %%
class FixedBatchQueue:
    def __init__(self, batch_size: int):
        # TODO
        raise NotImplementedError

    def add(self, item):
        # TODO
        raise NotImplementedError

    def pop_batch(self):
        # TODO
        raise NotImplementedError

# %% [markdown]
# ## 8. Stack
#
# Real-world ML use cases:
# - parsing configuration expressions
# - validating generated templates
# - expression handling in feature logic
#
# Question:
# Implement `is_valid_parentheses(text)` for `()`, `{}`, and `[]`.

# %%
def is_valid_parentheses(text: str) -> bool:
    # TODO
    raise NotImplementedError

# %% [markdown]
# ## 9. Graph Traversal
#
# Real-world ML use cases:
# - dependency graphs in feature pipelines
# - DAG validation
# - knowledge graph traversal
#
# Question:
# Given a dependency graph represented as a dictionary, implement `reachable_nodes(graph, start)` using BFS or DFS.

# %%
def reachable_nodes(graph: Dict[str, List[str]], start: str) -> List[str]:
    # TODO
    raise NotImplementedError

# %% [markdown]
# Follow-up:
# - How would you detect a cycle in a pipeline dependency graph?
# - Why is this important for orchestration systems?

# %% [markdown]
# ## 10. Dynamic Programming
#
# Real-world ML use cases:
# - sequence alignment
# - edit distance for text normalization
# - decoding problems
#
# Question:
# Implement `edit_distance(a, b)` returning Levenshtein distance between two strings.

# %%
def edit_distance(a: str, b: str) -> int:
    # TODO
    raise NotImplementedError

# %% [markdown]
# ## 11. Trie / Prefix Tree
#
# Real-world ML use cases:
# - autocomplete
# - prefix-based search
# - token dictionary lookup
#
# Question:
# Implement a simple Trie with methods:
# - `insert(word)`
# - `search(word)`
# - `starts_with(prefix)`

# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_word = False


class Trie:
    def __init__(self):
        # TODO
        raise NotImplementedError

    def insert(self, word: str):
        # TODO
        raise NotImplementedError

    def search(self, word: str) -> bool:
        # TODO
        raise NotImplementedError

    def starts_with(self, prefix: str) -> bool:
        # TODO
        raise NotImplementedError

# %% [markdown]
# ## 12. LRU Cache
#
# Real-world ML use cases:
# - caching model predictions
# - caching feature lookups
# - reducing repeated preprocessing cost
#
# Question:
# Implement `LRUCache(capacity)` with:
# - `get(key)`
# - `put(key, value)`

# %%
class LRUCache:
    def __init__(self, capacity: int):
        # TODO
        raise NotImplementedError

    def get(self, key):
        # TODO
        raise NotImplementedError

    def put(self, key, value):
        # TODO
        raise NotImplementedError

# %% [markdown]
# ## 13. Interval Merging
#
# Real-world ML use cases:
# - merging time ranges for user activity
# - combining overlapping annotation spans
# - post-processing detection windows
#
# Question:
# Implement `merge_intervals(intervals)`.

# %%
def merge_intervals(intervals: List[List[int]]) -> List[List[int]]:
    # TODO
    raise NotImplementedError

# %% [markdown]
# ## 14. Prefix Sum
#
# Real-world ML use cases:
# - efficient range aggregation
# - cumulative metrics computation
# - preprocessing for fast repeated queries
#
# Question:
# Build a class `PrefixSumArray(nums)` with method `range_sum(left, right)`.

# %%
class PrefixSumArray:
    def __init__(self, nums: List[int]):
        # TODO
        raise NotImplementedError

    def range_sum(self, left: int, right: int) -> int:
        # TODO
        raise NotImplementedError

# %% [markdown]
# ## 15. Two-Pointer Pattern
#
# Real-world ML use cases:
# - deduplicating sorted predictions
# - comparing aligned sequences
# - merging sorted candidate lists
#
# Question:
# Implement `deduplicate_sorted(nums)` that returns a new list with duplicates removed from a sorted list.

# %%
def deduplicate_sorted(nums: List[int]) -> List[int]:
    # TODO
    raise NotImplementedError

# %% [markdown]
# ## 16. Real-World ML Engineer Case Study
#
# Case:
# You are building an online feature service.
#
# Questions:
# - Which data structures would you use for fast feature lookup?
# - Where would caching help?
# - How would you maintain top-k recommendations efficiently?
# - How would you process streaming events in bounded memory?
# - Which operations must be O(1), O(log n), or O(n)?
#
# Write short answers below.

# %%
# Write your case study answers here

# %% [markdown]
# ## Validation Sandbox

# %%
# Example manual checks after implementation:
# top_k_tokens(["a", "b", "a", "c", "a", "b"], 2)
# first_threshold_crossing([0.1, 0.2, 0.8, 0.9], 0.75)
# top_n_predictions([("x", 0.3), ("y", 0.9), ("z", 0.5)], 2)
# running_top_k([1, 9, 3, 8, 2, 10], 3)
# max_average_window([1, 12, -5, -6, 50, 3], 4)
# find_insert_position([1, 3, 5, 7], 4)
# is_valid_parentheses("([]){}")
# reachable_nodes({"A": ["B", "C"], "B": ["D"], "C": [], "D": []}, "A")
# edit_distance("kitten", "sitting")
# merge_intervals([[1, 3], [2, 6], [8, 10], [15, 18]])
# deduplicate_sorted([1, 1, 2, 2, 3, 4, 4])
